# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q-1: Write a program to create an empty series.

# %%
pd.Series(np.zeros(4)*np.nan)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# dtype: float64

# %% [markdown]
# Q-2: Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
s1=pd.Series(np.arange(5))
s2=pd.Series(np.arange(5,10))

def series_operation(ser1,ser2):
    print(s1+s2)
    print(s1-s2)
    print(s1*s2)
    print(s1/s2)

series_operation(s1,s2)
# Out:
# 0     5
# 1     7
# 2     9
# 3    11
# 4    13
# dtype: int64
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64
# 0     0
# 1     6
# 2    14
# 3    24
# 4    36
# dtype: int64
# 0    0.000000
# 1    0.166667
# 2    0.285714
# 3    0.375000
# 4    0.444444
# dtype: float64

# %% [markdown]
# Q-3 Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
def compare(s1,s2):
    return s1>s2


compare(s1,s2)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
s1=pd.Series([2, 4, 6, 8, 10])
s2=pd.Series([1, 3, 5, 7, 10])

# %% [markdown]
# Q-5.Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.

# %%
def convert_dtype(s1,dtype_):
    return s1.astype(dtype_)

convert_dtype(s1,complex)
# Out:
# 0     2.0+ 0.0j
# 1     4.0+ 0.0j
# 2     6.0+ 0.0j
# 3     8.0+ 0.0j
# 4    10.0+ 0.0j
# dtype: complex128

# %% [markdown]
# Q-6 Find top 10 most run getter from the series.

# %%
runs=pd.read_csv('batsman_runs_series.csv').set_index('batter')['batsman_run']
runs
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %%
runs.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# Q-7 No of players having runs above 3000

# %%
runs[runs>3000]
# Out:
# batter
# AB de Villiers    5181
# AM Rahane         4074
# AT Rayudu         4190
# CH Gayle          4997
# DA Warner         5883
# F du Plessis      3403
# G Gambhir         4217
# KA Pollard        3437
# KD Karthik        4377
# KL Rahul          3895
# MK Pandey         3657
# MS Dhoni          4978
# RG Sharma         5881
# RV Uthappa        4954
# S Dhawan          6244
# SK Raina          5536
# SR Watson         3880
# SV Samson         3526
# V Kohli           6634
# YK Pathan         3222
# Name: batsman_run, dtype: int64

# %% [markdown]
# Q-8 No of players having runs above mean value?

# %%
runs[runs>runs.mean()].shape[0]
# Out:
# 128

# %% [markdown]
# Q-9
# i. Read `items.csv` making `item_name` as index.
# ii. Show no of nan values
# ii. Item price is given in $, so convert it to rupees without currency symbol.
# iii. Make data type of newly made series as float.
# iv. Fill nan with mean of the series
# How csv file looks
#
# item_name   item_price
#
# Chips and Fresh Tomato Salsa    $2.39
#
# Izze    $3.39
#
# Nantucket Nectar    $3.39
#
# Chips and Tomatillo-Green Chili Salsa   $2.39
#
# Chicken Bowl    $16.98

# %%
items=pd.read_csv('items.csv').set_index('item_name')['item_price']
items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
#No. of nan values

items.isna().sum()
# Out:
# np.int64(50)

# %% [markdown]
# Item price is given in $, so convert it to rupees without currency symbol

# %%
ser1=items.str.split("$").str[1].astype(float)  #Always use the str[] after str.split to get the elements 
s1=ser1*87

# %% [markdown]
# Q-10:
# i. Find mean price
# ii. Find 30th and 6th percentile value
# iii. Plot Histogram on price with bin size 50
# iv. No of items price lies between [1000 to 2000]

# %%
#Find the mean price

print(s1.mean())
# Out:
# 649.2837401574803

# %%
#Find 30th and 6th percentile value
print(s1.iloc[39])
print(s1.iloc[5])
# Out:
# 1022.25
# 955.26

# %%
s1.hist(bins=50)   #It groups numeric data into ranges (intervals) and counts how many values fall into each range

#If bin = 50 it means groups numeric data into ranges (intervals) and counts how many values fall into each range.

#Let's say we have a series from 0 to 9. Now, if we put bins=2, then it means create the intervals from 0-4 -> 5 values and 5-9,-> 5 values
# Out:
# <Axes: >

# %%
#No of items price lies between [1000 to 2000]

s1[(s1>1000) & (s1<2000)].shape[0]
# Out:
# 419
